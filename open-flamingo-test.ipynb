# %% [markdown]
# # Testing of OpenFlamingo
#
# Note that I couldn't seem to run it on macOS locally so I tried to run on google colab

# %% [markdown]
# ### Manage Dependencies

# %%
# %pip install -r requirements.txt
# %pip install open-flamingo[all]
# %pip install numpy==1.26.4
# %pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Requirement already satisfied: einops in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.8.1)
# Requirement already satisfied: einops-exts in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.0.4)
# Requirement already satisfied: transformers>=4.28.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (4.30.2)
# Requirement already satisfied: torch==2.0.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: pillow in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (11.1.0)
# Requirement already satisfied: open_clip_torch>=2.16.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: sentencepiece in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.1.98)
# Requirement already satisfied: filelock in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1->-r requirements.txt (line 4)) (3.18.0)
# Requirement already satisfied: typing-extensions in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: sympy in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: networkx in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1->-r requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: requests in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers>=4.28.1->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: torchvision in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from open_clip_torch>=2.16.0->-r requirements.txt (line 6)) (0.15.2)
# Requirement already satisfied: ftfy in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from open_clip_torch>=2.16.0->-r requirements.txt (line 6)) (6.3.1)
# Requirement already satisfied: timm in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from open_clip_torch>=2.16.0->-r requirements.txt (line 6)) (1.0.15)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=4.28.1->-r requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: wcwidth in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from ftfy->open_clip_torch>=2.16.0->-r requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from jinja2->torch==2.0.1->-r requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->transformers>=4.28.1->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->transformers>=4.28.1->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->transformers>=4.28.1->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->transformers>=4.28.1->-r requirements.txt (line 3)) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from sympy->torch==2.0.1->-r requirements.txt (line 4)) (1.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: no matches found: open-flamingo[all]
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (4.30.2)
# Collecting transformers
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/aa/22/733a6fc4a6445d835242f64c490fdd30f4a08d58f2b788613de3f9170692/transformers-4.50.3-py3-none-any.whl.metadata
#   Downloading transformers-4.50.3-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: filelock in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Obtaining dependency information for tokenizers<0.22,>=0.21 from https://files.pythonhosted.org/packages/ae/1a/4526797f3719b0287853f12c5ad563a9be09d446c44ac784cdd7c50f76ab/tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->transformers) (2025.1.31)
# Downloading transformers-4.50.3-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 45.8 MB/s eta 0:00:00 0:00:01
# Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 37.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.30.2
#     Uninstalling transformers-4.30.2:
#       Successfully uninstalled transformers-4.30.2
# Successfully installed tokenizers-0.21.1 transformers-4.50.3
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy==1.26.4 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch==2.0.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: torchvision==0.15.2 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (0.15.2)
# Requirement already satisfied: torchaudio==2.0.2 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (2.0.2)
# Requirement already satisfied: filelock in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1) (4.12.2)
# Requirement already satisfied: sympy in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torch==2.0.1) (3.1.6)
# Requirement already satisfied: numpy in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torchvision==0.15.2) (1.26.4)
# Requirement already satisfied: requests in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torchvision==0.15.2) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from torchvision==0.15.2) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->torchvision==0.15.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->torchvision==0.15.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from requests->torchvision==0.15.2) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/timothyleow/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages (from sympy->torch==2.0.1) (1.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Initialize Model

# %%
from open_flamingo import create_model_and_transforms

model, image_processor, tokenizer = create_model_and_transforms(
    clip_vision_encoder_path="ViT-L-14",
    clip_vision_encoder_pretrained="openai",
    lang_encoder_path="anas-awadalla/mpt-1b-redpajama-200b",
    tokenizer_path="anas-awadalla/mpt-1b-redpajama-200b",
    cross_attn_every_n_layers=1,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/utils/import_utils.py:1976, in _LazyModule._get_module(self, module_name)
#    1975 try:
# -> 1976     return importlib.import_module("." + module_name, self.__name__)
#    1977 except Exception as e:
#
# File ~/anaconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:55
#      54 from .integrations.flash_attention import flash_attention_forward
# ---> 55 from .integrations.flex_attention import flex_attention_forward
#      56 from .integrations.sdpa_attention import sdpa_attention_forward
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/integrations/flex_attention.py:46
#      41     from torch.nn.attention.flex_attention import (
#      42         create_block_mask as create_block_causal_mask_flex,
#      43     )
# ---> 46 class WrappedFlexAttention:
#      47     """
#      48     We are doing a singleton class so that flex attention is compiled once when it's first called.
#      49     """
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/integrations/flex_attention.py:61, in WrappedFlexAttention()
#      59     return cls._instance
# ---> 61 @torch.compiler.disable(recursive=False)
#      62 def __init__(self):
#      63     """
#      64     Initialize or update the singleton instance.
#      65     """
#
# AttributeError: module 'torch' has no attribute 'compiler'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 3
#       1 from open_flamingo import create_model_and_transforms
# ----> 3 model, image_processor, tokenizer = create_model_and_transforms(
#       4     clip_vision_encoder_path="ViT-L-14",
#       5     clip_vision_encoder_pretrained="openai",
#       6     lang_encoder_path="anas-awadalla/mpt-1b-redpajama-200b",
#       7     tokenizer_path="anas-awadalla/mpt-1b-redpajama-200b",
#       8     cross_attn_every_n_layers=1,
#       9 )
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/open_flamingo/src/factory.py:57, in create_model_and_transforms(clip_vision_encoder_path, clip_vision_encoder_pretrained, lang_encoder_path, tokenizer_path, cross_attn_every_n_layers, use_local_files, decoder_layers_attr_name, freeze_lm_embeddings, **flamingo_kwargs)
#      52 if text_tokenizer.pad_token is None:
#      53     # Issue: GPT models don't have a pad token, which we use to
#      54     # modify labels for the loss.
#      55     text_tokenizer.add_special_tokens({"pad_token": "<PAD>"})
# ---> 57 lang_encoder = AutoModelForCausalLM.from_pretrained(
#      58     lang_encoder_path,
#      59     local_files_only=use_local_files,
#      60     trust_remote_code=True,
#      61 )
#      63 # hacks for MPT-1B, which doesn't have a get_input_embeddings method
#      64 if "mpt-1b-redpajama-200b" in lang_encoder_path:
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:562, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     560 if has_remote_code and trust_remote_code:
#     561     class_ref = config.auto_map[cls.__name__]
# --> 562     model_class = get_class_from_dynamic_module(
#     563         class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     564     )
#     565     _ = hub_kwargs.pop("code_revision", None)
#     566     cls.register(config.__class__, model_class, exist_ok=True)
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/dynamic_module_utils.py:553, in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     540 # And lastly we get the class inside our newly created module
#     541 final_module = get_cached_module_file(
#     542     repo_id,
#     543     module_file + ".py",
#    (...)    551     repo_type=repo_type,
#     552 )
# --> 553 return get_class_in_module(class_name, final_module, force_reload=force_download)
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/dynamic_module_utils.py:250, in get_class_in_module(class_name, module_path, force_reload)
#     248 # reload in both cases, unless the module is already imported and the hash hits
#     249 if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 250     module_spec.loader.exec_module(module)
#     251     module.__transformers_module_hash__ = module_hash
#     252 return getattr(module, class_name)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.cache/huggingface/modules/transformers_modules/anas-awadalla/mpt-1b-redpajama-200b/50d6bc94e17812873f39c36c5f815263fa71fb80/mosaic_gpt.py:16
#      14 import torch.nn as nn
#      15 import torch.nn.functional as F
# ---> 16 from transformers import AutoTokenizer, PreTrainedModel
#      17 from transformers.modeling_outputs import CausalLMOutputWithPast
#      19 from .attention import attn_bias as module_attn_bias, attn_bias_shape as module_attn_bias_shape
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/utils/import_utils.py:1964, in _LazyModule.__getattr__(self, name)
#    1962     value = Placeholder
#    1963 elif name in self._class_to_module.keys():
# -> 1964     module = self._get_module(self._class_to_module[name])
#    1965     value = getattr(module, name)
#    1966 elif name in self._modules:
#
# File ~/Developer/CS4248_Dev/project/.venv/lib/python3.11/site-packages/transformers/utils/import_utils.py:1978, in _LazyModule._get_module(self, module_name)
#    1976     return importlib.import_module("." + module_name, self.__name__)
#    1977 except Exception as e:
# -> 1978     raise RuntimeError(
#    1979         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1980         f" traceback):\n{e}"
#    1981     ) from e
#
# RuntimeError: Failed to import transformers.modeling_utils because of the following error (look up to see its traceback):
# module 'torch' has no attribute 'compiler'

# %% [markdown]
# ### Few shot image captioning

# %%
from PIL import Image
import requests
import torch

"""
Step 1: Load images
"""
demo_image_one = Image.open(
    requests.get(
        "http://images.cocodataset.org/val2017/000000039769.jpg", stream=True
    ).raw
)

demo_image_two = Image.open(
    requests.get(
        "http://images.cocodataset.org/test-stuff2017/000000028137.jpg",
        stream=True
    ).raw
)

query_image = Image.open(
    requests.get(
        "http://images.cocodataset.org/test-stuff2017/000000028352.jpg", 
        stream=True
    ).raw
)


"""
Step 2: Preprocessing images
Details: For OpenFlamingo, we expect the image to be a torch tensor of shape 
 batch_size x num_media x num_frames x channels x height x width. 
 In this case batch_size = 1, num_media = 3, num_frames = 1,
 channels = 3, height = 224, width = 224.
"""
vision_x = [image_processor(demo_image_one).unsqueeze(0), image_processor(demo_image_two).unsqueeze(0), image_processor(query_image).unsqueeze(0)]
vision_x = torch.cat(vision_x, dim=0)
vision_x = vision_x.unsqueeze(1).unsqueeze(0)

"""
Step 3: Preprocessing text
Details: In the text we expect an  special token to indicate where an image is.
 We also expect an <|endofchunk|> special token to indicate the end of the text 
 portion associated with an image.
"""
tokenizer.padding_side = "left" # For generation padding tokens should be on the left
lang_x = tokenizer(
    ["An image of two cats.<|endofchunk|>An image of a bathroom sink.<|endofchunk|>An image of"],
    return_tensors="pt",
)


"""
Step 4: Generate text
"""
generated_text = model.generate(
    vision_x=vision_x,
    lang_x=lang_x["input_ids"],
    attention_mask=lang_x["attention_mask"],
    max_new_tokens=20,
    num_beams=3,
)

print("Generated text: ", tokenizer.decode(generated_text[0]))
